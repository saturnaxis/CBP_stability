# %% [markdown]
# # 03 — Paper Figure 5: stability surface

# %% [markdown]
# This notebook recreates **Figure 5** from Quarles et al. (2018) using the repository `a_crit.txt` table. The axes match the paper: binary mass ratio $\mu$ on the x-axis, binary eccentricity $e_{\rm bin}$ on the y-axis, and color-coded $a_c/a_{\rm bin}$.

# %%
from pathlib import Path
import os
if Path.cwd().name == 'examples':
    os.chdir('..')
print(Path.cwd())

# %%
from cbp_paper_figures import plot_figure5

fig, ax = plot_figure5('a_crit.txt', output='Q18_Fig5_notebook.png', dpi=300)

# %% [markdown]
# The output file `Q18_Fig5_notebook.png` is written in the repository root. White points show the Kepler circumbinary host-star locations in the same parameter space.
