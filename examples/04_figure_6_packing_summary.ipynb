# %% [markdown]
# # 04 — Paper Figure 6: dynamical-spacing schematic

# %% [markdown]
# This notebook recreates **Figure 6** from Quarles et al. (2018). It is a schematic, not a bar chart: the Kepler circumbinary planets are shown as concentric quarter-circles in dynamical spacing $\beta_c=(a_p-a_c)/R_{H,m}$. Red curves are systems below the equal-mass packing threshold, and the $\beta_c=7$ guide is included.

# %%
from pathlib import Path
import os
if Path.cwd().name == 'examples':
    os.chdir('..')
print(Path.cwd())

# %%
from cbp_paper_figures import plot_figure6

fig, ax = plot_figure6(output='Q18_Fig6_notebook.png', dpi=300)

# %% [markdown]
# The output file `Q18_Fig6_notebook.png` is written in the repository root. The values come from the Table 4 dynamical spacings used in the paper.
