# %% [markdown]
# # 00 — Interpolation quickstart

# %% [markdown]
# These notebooks are meant to be run from the repository root. If you open one from the `examples/` folder, the first code cell below moves Python to the parent directory so local modules such as `cbp_stability.py` can be imported.

# %%
from pathlib import Path
import os
if Path.cwd().name == 'examples':
    os.chdir('..')
print(Path.cwd())

# %%
from cbp_stability import build_stability_grid, get_ac, critical_period_days, q_to_mu

grid = build_stability_grid()
mu = q_to_mu(0.2994)
e_bin = 0.15894
p_bin_days = 41.077580
print(f'a_c = {get_ac(mu, e_bin, grid=grid):.3f}')
print(f'P_c = {critical_period_days(mu, e_bin, p_bin_days, grid=grid):.3f} days')

# %%
# Command-line equivalent:
# python get_ac.py 0.230 0.159 --p-bin-days 41.07758
